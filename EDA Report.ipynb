# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
## libaries for EDA
from pandas_profiling import ProfileReport
import sweetviz as sv

# %%
#set maximum columns
pd.set_option('display.max_columns', None)

# %%
### Import dataset
df = pd.read_csv("Online Study Good Or Bad_.csv")
df.head()
# Out:
#                          Timestamp Enter Your Name   \
# 0  2021/09/23 11:36:58 pm GMT+5:30            Vikas
# 1  2021/09/23 11:47:13 pm GMT+5:30     Harsh Dahiya
# 2  2021/09/23 11:49:37 pm GMT+5:30           Aditya
# 3  2021/09/23 11:50:35 pm GMT+5:30           CHIRAG
# 4  2021/09/24 12:02:02 am GMT+5:30            Rahul
#
#   What is the highest degree or level of education you have completed?  \
# 0                                     Under Graduate
# 1                                     Under Graduate
# 2                                     Under Graduate
# 3                                     Under Graduate
# 4                                                PhD
#
#   What gender do you identify as? Where is your home located?  \
# 0                            Male                       Delhi
# 1                            Male                       Delhi
# 2                            Male                 India Delhi
# ...

# %%
data = df.drop(columns = ["Timestamp","Enter Your Name "])

# %%
data.head()
# Out:
#   What is the highest degree or level of education you have completed?  \
# 0                                     Under Graduate
# 1                                     Under Graduate
# 2                                     Under Graduate
# 3                                     Under Graduate
# 4                                                PhD
#
#   What gender do you identify as? Where is your home located?  \
# 0                            Male                       Delhi
# 1                            Male                       Delhi
# 2                            Male                 India Delhi
# 3                            Male                       Delhi
# 4               Prefer not to say                       Delhi
#
#   Are you _________ ?  \
# 0             Student
# 1             Student
# 2             Student
# 3             Student
# 4             Teacher
#
#    Does COVID-19 pandemic affect your education in any way?  \
# ...

# %%
sweet_report = sv.analyze(data)
sweet_report.show_html("Sweetviz_EDA.html")
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report Sweetviz_EDA.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
prof = ProfileReport(data,explorative = True)
prof.to_file("Pandas_profiling_EDA.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#EDA using Autoviz
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
autoviz = AV.AutoViz("Online Study Good Or Bad_.csv",verbose = 0)
# Out:
# Imported AutoViz_Class version: 0.0.81. Call using:
#     from autoviz.AutoViz_Class import AutoViz_Class
#     AV = AutoViz_Class()
#     AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
# Note: verbose=0 or 1 generates charts and displays them in your local Jupyter notebook.
#       verbose=2 saves plots in your local machine under AutoViz_Plots directory and does not display charts.
# Shape of your Data Set: (60, 43)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  3
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  18
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  2
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  1
# ...
